# %% [markdown]
# <a href="https://colab.research.google.com/github/greengerong/awesome-llm/blob/main/colab/Qwen_14B_Chat_Int4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers bitsandbytes accelerate torch tiktoken transformers_stream_generator einops scipy
# !pip install auto-gptq optimum

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# Note: The default behavior now has injection attack prevention off.
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen-14B-Chat-Int4", trust_remote_code=True)

model = AutoModelForCausalLM.from_pretrained(
    "Qwen/Qwen-14B-Chat-Int4",
    device_map="auto",
    trust_remote_code=True
).eval()
response, history = model.chat(tokenizer, "你好，请实现Java快速排序算法", history=None)
print(response)
# 你好！很高兴为你提供帮助。
# Out:
# WARNING:transformers_modules.Qwen.Qwen-14B-Chat-Int4.5f04b835883a88a86348b0c85c8d9fc13d77ce97.modeling_qwen:Warning: please make sure that you are using the latest codes and checkpoints, especially if you used Qwen-7B before 09.25.2023.请使用最新模型和代码，尤其如果你在9月25日前已经开始使用Qwen-7B，千万注意不要使用错误代码和模型。
# WARNING:transformers_modules.Qwen.Qwen-14B-Chat-Int4.5f04b835883a88a86348b0c85c8d9fc13d77ce97.modeling_qwen:Try importing flash-attention for faster inference...
# WARNING:transformers_modules.Qwen.Qwen-14B-Chat-Int4.5f04b835883a88a86348b0c85c8d9fc13d77ce97.modeling_qwen:Warning: import flash_attn rotary fail, please install FlashAttention rotary to get higher efficiency https://github.com/Dao-AILab/flash-attention/tree/main/csrc/rotary
# ...
