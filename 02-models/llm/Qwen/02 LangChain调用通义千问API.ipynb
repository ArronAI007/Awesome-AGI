# %%
# !pip install langchain langchainhub dashscope langchain_community
# Out:
# Collecting langchain
#   Downloading langchain-0.2.0-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.7/973.7 kB 7.8 MB/s eta 0:00:00
# Collecting langchainhub
#   Downloading langchainhub-0.1.15-py3-none-any.whl (4.6 kB)
# Collecting dashscope
#   Downloading dashscope-1.19.1-py3-none-any.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_core-0.2.0-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.9/307.9 kB 14.7 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain)
#   Downloading langchain_text_splitters-0.2.0-py3-none-any.whl (23 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Downloading langsmith-0.1.59-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.2/121.2 kB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.3.0)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub)
#   Downloading types_requests-2.31.0.20240406-py3-none-any.whl (15 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 5.2 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.7 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 15.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.18.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.2.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: types-requests, packaging, orjson, mypy-extensions, jsonpointer, typing-inspect, marshmallow, langchainhub, jsonpatch, langsmith, dataclasses-json, dashscope, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dashscope-1.19.1 dataclasses-json-0.6.6 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.0 langchain-core-0.2.0 langchain-text-splitters-0.2.0 langchainhub-0.1.15 langsmith-0.1.59 marshmallow-3.21.2 mypy-extensions-1.0.0 orjson-3.10.3 packaging-23.2 types-requests-2.31.0.20240406 typing-inspect-0.9.0

# %%
#!pip install langchain langchainhub dashscope
from langchain_core.prompts import ChatPromptTemplate
from langchain.chains import LLMChain
from langchain_community.llms import Tongyi
from langchain import hub
import os

prompt1 = ChatPromptTemplate.from_template("""{input}
"""
    )
os.environ["DASHSCOPE_API_KEY"] = "sk-xxx" # https://dashscope.console.aliyun.com/
llm = Tongyi(model="qwen1.5-14b-chat")

chain_one = LLMChain(
    llm=llm,
    prompt=prompt1,
    verbose=False
)

print(chain_one.invoke("深圳1998年的情况介绍"))
print(chain_one.invoke("HTML入门"))
print(chain_one.invoke("什么是深度学习"))
# Out:
# {'input': '深圳1998年的情况介绍', 'text': '1998年的深圳，正处于中国改革开放的深入发展阶段，是中国经济特区中的重要城市。这一年，深圳的经济社会发展有以下几个主要特点：\n\n1. 经济发展：1998年，深圳的经济发展继续保持高速，GDP达到1205亿元人民币，比上一年有显著增长。深圳的工业、服务业和高科技产业都取得了显著的发展，尤其是电子信息产业，已经成为了深圳的主导产业。\n\n2. 改革开放：深圳作为中国最早的一批经济特区，1998年继续深化改革开放政策，吸引了大量国内外投资。这一年，深圳的外商直接投资持续增加，许多跨国公司在此设立了分公司或研发中心。\n\n3. 基础设施建设：1998年，深圳的城市基础设施建设也在加速，包括道路、桥梁、港口、机场等都在扩建和升级，为经济发展提供了有力支撑。\n\n4. 社会事业：在社会事业发展方面，深圳的教育、医疗、文化等公共服务体系逐步完善，居民生活水平不断提高。同时，深圳也开始注重环境保护和可持续发展，开始实施一系列的环保政策。\n\n5. 金融改革：1998年，深圳在金融改革方面也有所突破，深圳证券交易所的运作更加规范，为中国资本市场的健康发展起到了推动作用。\n\n总的来说，1998年的深圳是一个充满活力和创新的城市，它的快速发展不仅对中国，也对全球产生了深远影响。'}
# {'input': 'HTML入门', 'text': 'HTML（HyperText Markup Language）是用于创建网页的标准标记语言。以下是一些基础的HTML入门知识：\n\n1. **HTML结构**：HTML文件由一系列的元素组成，每个元素都是在一对尖括号 `<>` 中。元素可以是标签、文本、属性等。\n\n2. **HTML标签**：HTML标签告诉浏览器如何显示内容。例如，`<html>` 是文档的根元素，`<head>` 包含元数据，`<body>` 包含可见内容。文本内容需要放在段落标签 `<p>` 中，标题则使用 `<h1>` 到 `<h6>` 标签，其中 `<h1>` 是最大的标题。\n\n3. **链接**：使用 `<a>` 标签创建超链接，如 `<a href="http://www.example.com">这是一个链接</a>`。\n\n4. **图像**：使用 `<img>` 标签插入图片，如 `<img src="image.jpg" alt="描述性文字">`。\n\n5. **列表**：无序列表使用 `<ul>` 和 `<li>` 标签，有序列表使用 `<ol>` 和 `<li>` 标签。\n\n6. **样式**：HTML中的样式通常通过CSS（Cascading Style Sheets）来定义。你可以使用 `style` 属性直接在HTML元素中添加样式，如 `<p style="color: red;">这是红色的文本</p>`。\n\n7. **注释**：在HTML中，`<!-- 这是一个注释 -->` 用来添加注释，这对开发者来说很有用，但浏览器会忽略它。\n\n8. **学习资源**：要深入学习HTML，可以参考W3Schools（https://www.w3schools.com/html/）或MDN Web Docs（https://developer.mozilla.org/en-US/docs/Web/HTML）等在线教程。\n\n开始编写一个简单的HTML页面，可以这样写：\n\n```html\n<!DOCTYPE html>\n<html>\n<head>\n    <title>我的第一个HTML页面</title>\n</head>\n<body>\n    <h1>欢迎来到我的网站！</h1>\n    <p>这是一个段落。</p>\n    <a href="http://www.example.com">访问示例网站</a>\n</body>\n</html>\n```\n\n保存这个文件为.html或.htm扩展名，然后用浏览器打开，你就能看到你的第一个HTML页面了。'}
# {'input': '什么是深度学习', 'text': '深度学习是一种人工智能技术，它允许计算机通过模仿人脑的工作方式来学习和改进。它是一种机器学习的方法，其核心思想是构建深度神经网络，这些网络由多个层次组成，每一层都对输入数据进行处理，以提取更复杂的特征。通过大量的训练，深度学习模型可以自动学习到数据的内在规律和表示，从而实现诸如图像识别、语音识别、自然语言处理等任务。'}
